# %% [markdown]
# <a href="https://colab.research.google.com/github/szdziedzic/detr/blob/main/results/sample_train_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Make a directory to store the dataset
# !mkdir -p datasets/coco

# Download the dataset
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/val2017.zip
# !wget http://images.cocodataset.org/zips/test2017.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip

# Unzip the downloaded files to the data directory
# !unzip -q train2017.zip -d datasets/coco
# !unzip -q val2017.zip -d datasets/coco
# !unzip -q test2017.zip -d datasets/coco
# !unzip -q annotations_trainval2017.zip -d datasets/coco

# !rm train2017.zip
# !rm val2017.zip
# !rm test2017.zip
# !rm annotations_trainval2017.zip
# Out:
# --2024-01-21 18:30:36--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.164.193, 52.216.56.97, 54.231.232.25, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.164.193|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  47.3MB/s    in 6m 33s
#
# 2024-01-21 18:37:09 (46.9 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]
#
# --2024-01-21 18:37:09--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.29.67, 3.5.9.108, 54.231.162.65, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.29.67|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# ...

# %%
# !pip install cython scipy pycocotools

# %%
# !pip install git+https://github.com/cocodataset/panopticapi.git
# Out:
# ...
#   Cloning https://github.com/cocodataset/panopticapi.git to /tmp/pip-req-build-8ylgi4_j
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/panopticapi.git /tmp/pip-req-build-8ylgi4_j
#   Resolved https://github.com/cocodataset/panopticapi.git to commit 7bb4655548f98f3fedc07bf37e9040a992b054b0
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panopticapi: filename=panopticapi-0.1-py3-none-any.whl size=8259 sha256=cec01e206f45cf8dc8968129b1773b3c70f4b08467ea127fb0663a1b0ae9908f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7jmg0mu3/wheels/70/87/ae/5c2b138c967549070e3fe35f3b5fcaf1ed56e9f5483a09ee65
# Successfully built panopticapi
# ...

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/szdziedzic/detr.git
# Out:
# Cloning into 'detr'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 332 (delta 48), reused 55 (delta 24), pack-reused 247
# Receiving objects: 100% (332/332), 355.67 KiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
# !cd detr && git pull
# Out:
# Already up to date.

# %%
import wandb

wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python detr/main.py --coco_path ./datasets/coco --detr_variant detrmae --output_dir .
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [1]  [24880/59143]  eta: 0:43:04  lr: 0.000100  class_error: 64.00  loss: 2.9419 (3.0671)  loss_ce: 1.0806 (1.1361)  loss_bbox: 0.6575 (0.7902)  loss_giou: 1.0588 (1.1407)  loss_ce_unscaled: 1.0806 (1.1361)  class_error_unscaled: 71.4286 (75.4177)  loss_bbox_unscaled: 0.1315 (0.1580)  loss_giou_unscaled: 0.5294 (0.5704)  cardinality_error_unscaled: 8.0000 (7.7826)  time: 0.0698  data: 0.0089  max mem: 559
# Epoch: [1]  [24890/59143]  eta: 0:43:03  lr: 0.000100  class_error: 57.14  loss: 2.8492 (3.0671)  loss_ce: 1.0431 (1.1361)  loss_bbox: 0.7318 (0.7902)  loss_giou: 1.1602 (1.1407)  loss_ce_unscaled: 1.0431 (1.1361)  class_error_unscaled: 77.7778 (75.4181)  loss_bbox_unscaled: 0.1464 (0.1580)  loss_giou_unscaled: 0.5801 (0.5704)  cardinality_error_unscaled: 6.0000 (7.7830)  time: 0.0675  data: 0.0084  max mem: 559
# ...
